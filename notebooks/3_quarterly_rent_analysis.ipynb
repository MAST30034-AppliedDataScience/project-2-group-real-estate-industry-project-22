# %%
from urllib.request import urlretrieve
import os

# from the current `tute_1` directory, go back two levels to the `MAST30034` directory
output_relative_dir = '../data/landing'

# check if it exists as it makedir will raise an error if it does exist
if not os.path.exists(output_relative_dir):
    os.makedirs(output_relative_dir)

# %%
URL_24 = "https://www.dffh.vic.gov.au/moving-annual-rent-suburb-march-quarter-2024-excel"

# %%
output_dir_24 = f"{output_relative_dir}/2024.xlsx"
# download
urlretrieve(URL_24, output_dir_24)
# Out:
# ('../data/landing/2024.xlsx', <http.client.HTTPMessage at 0x7f04e8e7a500>)

# %%
import pandas as pd
import openpyxl

# %%
df_24 = pd.read_excel('../data/landing/2024.xlsx', engine="openpyxl", sheet_name=None)

# Flat dataframes
flat_1b = df_24["1 bedroom flat"]
flat_2b = df_24["2 bedroom flat"]
flat_3b = df_24["3 bedroom flat"]

# House dataframes
house_2b = df_24["2 bedroom house"]
house_3b = df_24["3 bedroom house"]
house_4b = df_24["4 bedroom house"]

# All properties 
all_props = df_24["All properties"]

flat_1b.head()
# Out:
#   Moving annual rent by suburb                             Unnamed: 1  \
# 0               1 bedroom flat                                    NaN
# 1                          NaN                                    NaN
# 2              Inner Melbourne  Albert Park-Middle Park-West St Kilda
# 3                          NaN                               Armadale
# 4                          NaN                          Carlton North
#
#   Lease commenced in year ending  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                        Mar 2000        NaN   Jun 2000        NaN   Sep 2000
# 1                           Count     Median      Count     Median      Count
# 2                             352        165        347        165        378
# 3                             210        150        212        150        213
# 4                              87        150         78        155         74
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 186 Unnamed: 187  \
# ...

# %%
# Median rent dataframe
med_flat_1b = flat_1b.iloc[:, 1::2]
med_flat_2b = flat_2b.iloc[:, 1::2]
med_flat_3b = flat_3b.iloc[:, 1::2]

med_house_2b = house_2b.iloc[:, 1::2]
med_house_3b = house_3b.iloc[:, 1::2]
med_house_4b = house_4b.iloc[:, 1::2]

med_all_props = all_props.iloc[:, 1::2]


med_all_props.head()
# Out:
#                               Unnamed: 1 Unnamed: 3 Unnamed: 5 Unnamed: 7  \
# 0                                    NaN        NaN        NaN        NaN
# 1                                    NaN     Median     Median     Median
# 2  Albert Park-Middle Park-West St Kilda        260        260        270
# 3                               Armadale        200        200        205
# 4                          Carlton North        260        260        265
#
#   Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17 Unnamed: 19  ...  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN  ...
# 1     Median      Median      Median      Median      Median      Median  ...
# 2        275         275         280         280         290         300  ...
# 3        210         215         220         225         230         233  ...
# 4        270         270         275         280         280         290  ...
#
# ...

# %%
months = ['march', 'june', 'september', 'december']
years = range(2000, 2024)  # 2024 is not included

# Initialize an empty list to store the results
new_header = ['suburbs']

# Loop through each year and each month
for year in years:
    for month in months:
        new_header.append(f"{month}_{year}")

new_header.append(f"march_2024")
# Print the result
print(new_header)
# Out:
# ['suburbs', 'march_2000', 'june_2000', 'september_2000', 'december_2000', 'march_2001', 'june_2001', 'september_2001', 'december_2001', 'march_2002', 'june_2002', 'september_2002', 'december_2002', 'march_2003', 'june_2003', 'september_2003', 'december_2003', 'march_2004', 'june_2004', 'september_2004', 'december_2004', 'march_2005', 'june_2005', 'september_2005', 'december_2005', 'march_2006', 'june_2006', 'september_2006', 'december_2006', 'march_2007', 'june_2007', 'september_2007', 'december_2007', 'march_2008', 'june_2008', 'september_2008', 'december_2008', 'march_2009', 'june_2009', 'september_2009', 'december_2009', 'march_2010', 'june_2010', 'september_2010', 'december_2010', 'march_2011', 'june_2011', 'september_2011', 'december_2011', 'march_2012', 'june_2012', 'september_2012', 'december_2012', 'march_2013', 'june_2013', 'september_2013', 'december_2013', 'march_2014', 'june_2014', 'september_2014', 'december_2014', 'march_2015', 'june_2015', 'september_2015', 'december_2
# ...

# %%
med_flat_1b.columns = new_header
med_flat_2b.columns = new_header
med_flat_3b.columns = new_header

med_house_2b.columns = new_header
med_house_3b.columns = new_header
med_house_4b.columns = new_header

med_all_props.columns = new_header

print(med_all_props)
# Out:
#                                    suburbs march_2000 june_2000  \
# 0                                      NaN        NaN       NaN
# 1                                      NaN     Median    Median
# 2    Albert Park-Middle Park-West St Kilda        260       260
# 3                                 Armadale        200       200
# 4                            Carlton North        260       260
# ..                                     ...        ...       ...
# 156                            Wanagaratta        125       125
# 157                               Warragul        130       135
# 158                            Warrnambool        130       135
# 159                                Wodonga        145       145
# 160                            Group Total        130       130
#
#     september_2000 december_2000 march_2001 june_2001 september_2001  \
# 0              NaN           NaN        NaN       NaN            NaN
# ...

# %%
m_flat_1b = med_flat_1b.iloc[2:]
m_flat_2b = med_flat_2b.iloc[2:]
m_flat_3b = med_flat_3b.iloc[2:]

m_house_2b = med_house_2b.iloc[2:]
m_house_3b = med_house_3b.iloc[2:]
m_house_4b = med_house_4b.iloc[2:]

m_all_props = med_all_props.iloc[2:]

m_all_props
# Out:
#                                    suburbs march_2000 june_2000  \
# 2    Albert Park-Middle Park-West St Kilda        260       260
# 3                                 Armadale        200       200
# 4                            Carlton North        260       260
# 5                        Carlton-Parkville        251       260
# 6                          CBD-St Kilda Rd        320       320
# ..                                     ...        ...       ...
# 156                            Wanagaratta        125       125
# 157                               Warragul        130       135
# 158                            Warrnambool        130       135
# 159                                Wodonga        145       145
# 160                            Group Total        130       130
#
#     september_2000 december_2000 march_2001 june_2001 september_2001  \
# 2              270           275        275       280            280
# ...

# %%
m_flat_1b = m_flat_1b[m_flat_1b['suburbs'].str.lower() != 'group total']
m_flat_2b = m_flat_2b[m_flat_2b['suburbs'].str.lower() != 'group total']
m_flat_3b = m_flat_3b[m_flat_3b['suburbs'].str.lower() != 'group total']

m_house_2b = m_house_2b[m_house_2b['suburbs'].str.lower() != 'group total']
m_house_3b = m_house_3b[m_house_3b['suburbs'].str.lower() != 'group total']
m_house_4b = m_house_4b[m_house_4b['suburbs'].str.lower() != 'group total']

m_all_props = m_all_props[m_all_props['suburbs'].str.lower() != 'group total']
m_all_props
# Out:
#                                    suburbs march_2000 june_2000  \
# 2    Albert Park-Middle Park-West St Kilda        260       260
# 3                                 Armadale        200       200
# 4                            Carlton North        260       260
# 5                        Carlton-Parkville        251       260
# 6                          CBD-St Kilda Rd        320       320
# ..                                     ...        ...       ...
# 155                              Traralgon        125       120
# 156                            Wanagaratta        125       125
# 157                               Warragul        130       135
# 158                            Warrnambool        130       135
# 159                                Wodonga        145       145
#
#     september_2000 december_2000 march_2001 june_2001 september_2001  \
# 2              270           275        275       280            280
# ...

# %% [markdown]
# ### [Liveability Index]
# ### Finding the log average of median monthly rent for each suburb from 2000 - 2024

# %%
import numpy as np 
def log_average(df):
    

    # Initialize an empty list to store log_mean values
    log_mean_list = []

    # Convert DataFrame to a list of lists
    rows_list = df.iloc[:, 1:].values.tolist()

    for rows in rows_list:
        series = pd.to_numeric(rows, errors='coerce')
        series = series.astype(float)

        log_values = np.log(series)
        log_mean = np.mean(log_values)
        log_mean_list.append(log_mean)

    # Create a new DataFrame with the log_mean data
    log_mean_df = pd.DataFrame(log_mean_list)
    return log_mean_df


m_sub_f1b = log_average(m_flat_1b)
m_sub_f2b = log_average(m_flat_2b)
m_sub_f3b = log_average(m_flat_3b)

m_sub_h2b = log_average(m_house_2b)
m_sub_h3b = log_average(m_house_3b)
m_sub_h4b = log_average(m_house_4b)

m_sub_all = log_average(m_all_props)
m_sub_df = pd.DataFrame(m_all_props['suburbs'])

m_sub_df.reset_index(drop=True, inplace=True)
m_sub_f1b.reset_index(drop=True, inplace=True)
m_sub_f2b.reset_index(drop=True, inplace=True)
m_sub_f3b.reset_index(drop=True, inplace=True)
m_sub_h2b.reset_index(drop=True, inplace=True)
m_sub_h3b.reset_index(drop=True, inplace=True)
m_sub_h4b.reset_index(drop=True, inplace=True)
m_sub_all.reset_index(drop=True, inplace=True)


m_sub_df = pd.concat([m_sub_df,m_sub_f1b,m_sub_f2b,m_sub_f3b, 
                        m_sub_h2b,m_sub_h3b,m_sub_h4b,
                        m_sub_all],
                        keys=['suburbs','log_mean_1B_flats','log_mean_2B_flats','log_mean_3B_flats',
                        'log_mean_2B_houses', 'log_mean_3B_houses','log_mean_4B_houses',
                        'log_mean_all_properties'], axis =1)
m_sub_df.head()


                        
# test = m_sub_df[m_sub_df['suburbs'] == 'Albert Park-Middle Park-West St Kilda']
# print(test)
# Out:
#                                  suburbs log_mean_1B_flats log_mean_2B_flats  \
#                                  suburbs                 0                 0
# 0  Albert Park-Middle Park-West St Kilda          5.641679          5.982409
# 1                               Armadale          5.575333          5.859619
# 2                          Carlton North          5.569771          5.896137
# 3                      Carlton-Parkville          5.685395          6.015013
# 4                        CBD-St Kilda Rd          5.836967          6.144565
#
#   log_mean_3B_flats log_mean_2B_houses log_mean_3B_houses log_mean_4B_houses  \
#                   0                  0                  0                  0
# 0          6.370836           6.217150           6.535876           6.818589
# 1          6.248455           6.189722           6.497977                NaN
# 2          6.222246           6.078405           6.299134                NaN
# ...

# %%
# Replace NaN values with 0
m_sub_df_filled = m_sub_df.fillna(0)

print(m_sub_df_filled)
# Out:
#                                    suburbs log_mean_1B_flats  \
#                                    suburbs                 0
# 0    Albert Park-Middle Park-West St Kilda          5.641679
# 1                                 Armadale          5.575333
# 2                            Carlton North          5.569771
# 3                        Carlton-Parkville          5.685395
# 4                          CBD-St Kilda Rd          5.836967
# ..                                     ...               ...
# 141                              Traralgon          4.873482
# 142                            Wanagaratta          4.924760
# 143                               Warragul          0.000000
# 144                            Warrnambool          4.997001
# 145                                Wodonga          4.956283
#
#     log_mean_2B_flats log_mean_3B_flats log_mean_2B_houses log_mean_3B_houses  \
#                     0                 0                  0                  0
# ...

# %%
# m_sub_df['Average of 1-2 Bedders'] = m_sub_df[['Log Mean 1B Flats', 'Log Mean 2B Flats', 'Log Mean 2B Houses']].mean(axis=1)
# m_sub_df['Average of 3+ Bedders'] = m_sub_df[['Log Mean 3B Flats', 'Log Mean 2B Houses', 'Log Mean 4B Houses']].mean(axis=1)


## create benchmarks for each of the property type:
benchmark_f1b = m_sub_df['log_mean_1B_flats'].mean()
benchmark_f2b = m_sub_df['log_mean_2B_flats'].mean()
benchmark_f3b = m_sub_df['log_mean_3B_flats'].mean()

benchmark_h2b = m_sub_df['log_mean_2B_houses'].mean()
benchmark_h3b = m_sub_df['log_mean_3B_houses'].mean()
benchmark_h4b = m_sub_df['log_mean_4B_houses'].mean()

benchmark_all = m_sub_df['log_mean_all_properties'].mean()
benchmark_f1b
# Out:
# 0    5.338292
# dtype: float64

# %%
## Calculate =RAI (Rent Affordability Index) for 2 Categories of Property Types via 3-d directional vectors 
median_household_income = 1104 # 2022
# https://www.abs.gov.au/statistics/measuring-what-matters/measuring-what-matters-themes-and-indicators/prosperous/household-income-and-wealth


def calculate_RAI(median_rent, median_income):   # x is the log mean where as y is the benchmark 
    RAI_list = []

    for row in median_rent:
        if (row != '-'):
            RAI = (median_income/row) * 100
        
        RAI_list.append(RAI)
    return RAI_list

RAI_df = pd.DataFrame()
RAI_df['suburbs'] = m_flat_1b['suburbs']
RAI_df['f1B_RAI'] = calculate_RAI(m_flat_1b['march_2024'],median_household_income)
RAI_df['f2B_RAI'] = calculate_RAI(m_flat_2b['march_2024'],median_household_income)
RAI_df['f3B_RAI'] = calculate_RAI(m_flat_3b['march_2024'],median_household_income)

RAI_df['h2B_RAI'] = calculate_RAI(m_house_2b['march_2024'],median_household_income)
RAI_df['h3B_RAI'] = calculate_RAI(m_house_3b['march_2024'],median_household_income)
RAI_df['h4B_RAI'] = calculate_RAI(m_house_4b['march_2024'],median_household_income)

RAI_df['all_RAI'] = calculate_RAI(m_all_props['march_2024'],median_household_income)


RAI_df.head()
# Out:
#                                  suburbs     f1B_RAI     f2B_RAI     f3B_RAI  \
# 2  Albert Park-Middle Park-West St Kilda  259.764706  184.000000  128.372093
# 3                               Armadale  256.744186  193.684211  122.666667
# 4                          Carlton North  276.000000  200.727273  157.714286
# 5                      Carlton-Parkville  245.333333  172.500000  130.650888
# 6                        CBD-St Kilda Rd  200.727273  157.714286  110.400000
#
#       h2B_RAI     h3B_RAI     h4B_RAI     all_RAI
# 2  149.593496   96.842105   74.847458  169.846154
# 3  142.451613  105.142857   83.320755  197.142857
# 4  161.167883  122.666667   92.000000  162.352941
# 5  169.846154  134.143378  100.363636  193.684211
# 6  169.846154  134.143378  100.363636  172.500000

# %%
# ## Calculate Euclidean Distances for 2 Categories of Property Types via 3-d directional vectors 
# ## Positive affordability would be more affordable and negative affordability would mean less affordable.

# def sum_directional_vector_3d (x1,x2,x3,y1,y2,y3):   # x is the log mean where as y is the benchmark 
#     metrics = []

    
#     rows_list1 = x1.values.tolist()
#     rows_list2 = x2.values.tolist()
#     rows_list3 = x3.values.tolist()
#     rows_list1 = pd.to_numeric(rows_list1, errors='coerce')
#     rows_list2 = pd.to_numeric(rows_list2, errors='coerce')
#     rows_list3 = pd.to_numeric(rows_list3, errors='coerce')
    

#     for (val1, val2, val3) in zip(rows_list1, rows_list2, rows_list3):
#         total = 0
#         #vectors 
#         v1 = y1 - val1
#         v2 = y2 - val2 
#         v3 = y3 - val3 
#         total += v1 + v2 + v3

#         total = (total.tolist())
#         total = total[0]
        
        
#         metrics.append(total)
#     return metrics

# m_sub_df_filled['1-2 Bedder Affordability Metrics'] = sum_directional_vector_3d(m_sub_df_filled['Log Mean 1B Flats'],m_sub_df_filled['Log Mean 2B Flats'],
#                                                 m_sub_df_filled['Log Mean 2B Houses'], benchmark_f1b, benchmark_f2b, benchmark_h2b )
# m_sub_df_filled['3+ Bedder Affordability Metrics'] = sum_directional_vector_3d(m_sub_df_filled['Log Mean 3B Flats'],m_sub_df_filled['Log Mean 3B Houses'],
#                                                 m_sub_df_filled['Log Mean 4B Houses'], benchmark_f1b, benchmark_f2b, benchmark_h2b )


# m_sub_df_filled.head()

# %% [markdown]
# ### Time Series Plots Pre-Processing

# %%
# Count rent dataframe
count_flat_1b = flat_1b.iloc[:, 2::2]
count_flat_2b = flat_2b.iloc[:, 2::2]
count_flat_3b = flat_3b.iloc[:, 2::2]

count_house_2b = house_2b.iloc[:, 2::2]
count_house_3b = house_3b.iloc[:, 2::2]
count_house_4b = house_4b.iloc[:, 2::2]

count_all_props = all_props.iloc[:, 2::2]

count_house_4b.head()
# Out:
#   Lease commenced in year ending  Unnamed: 4 Unnamed: 6 Unnamed: 8  \
# 0                        Mar 2000   Jun 2000   Sep 2000   Dec 2000
# 1                           Count      Count      Count      Count
# 2                              19         21         24         22
# 3                              11         12         14         14
# 4                              78         78         76         70
#
#   Unnamed: 10 Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18 Unnamed: 20  \
# 0    Mar 2001    Jun 2001    Sep 2001    Dec 2001    Mar 2002    Jun 2002
# 1       Count       Count       Count       Count       Count       Count
# 2          23          30          26          24          23          18
# 3          15          19          18          23          20          14
# 4          50          44          38          34          28          30
#
#    ... Unnamed: 176 Unnamed: 178 Unnamed: 180 Unnamed: 182 Unnamed: 184  \
# ...

# %%
# dataframe of column of suburbs
c_sub_f_1b = flat_1b.iloc[:,1]
c_sub_f_2b = flat_2b.iloc[:,1]
c_sub_f_3b = flat_3b.iloc[:,1]

c_sub_h_2b = house_2b.iloc[:,1]
c_sub_h_3b = house_3b.iloc[:,1]
c_sub_h_4b = house_4b.iloc[:,1]

c_sub_all_props = all_props.iloc[:,1]
c_sub_f_1b.head()
# Out:
# 0                                      NaN
# 1                                      NaN
# 2    Albert Park-Middle Park-West St Kilda
# 3                                 Armadale
# 4                            Carlton North
# Name: Unnamed: 1, dtype: object

# %%
c_flat_1b = pd.concat([c_sub_f_1b,count_flat_1b], axis=1)
c_flat_2b = pd.concat([c_sub_f_2b,count_flat_2b], axis=1)
c_flat_3b = pd.concat([c_sub_f_3b,count_flat_3b], axis=1)

c_house_2b = pd.concat([c_sub_h_2b,count_house_2b], axis=1)
c_house_3b = pd.concat([c_sub_h_3b,count_house_3b], axis=1)
c_house_4b = pd.concat([c_sub_h_4b,count_house_4b], axis=1)

c_all_props = pd.concat([c_sub_all_props,count_all_props], axis=1)

c_house_4b.head()
# Out:
#                               Unnamed: 1 Lease commenced in year ending   \
# 0                                    NaN                        Mar 2000
# 1                                    NaN                           Count
# 2  Albert Park-Middle Park-West St Kilda                              19
# 3                               Armadale                              11
# 4                          Carlton North                              78
#
#   Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14  \
# 0   Jun 2000   Sep 2000   Dec 2000    Mar 2001    Jun 2001    Sep 2001
# 1      Count      Count      Count       Count       Count       Count
# 2         21         24         22          23          30          26
# 3         12         14         14          15          19          18
# 4         78         76         70          50          44          38
#
#   Unnamed: 16 Unnamed: 18  ... Unnamed: 176 Unnamed: 178 Unnamed: 180  \
# ...

# %%
nan_rows = c_all_props[c_all_props.isna().any(axis=1)]
nan_rows
# Out:
#   Unnamed: 1 Lease commenced in year ending  Unnamed: 4 Unnamed: 6 Unnamed: 8  \
# 0        NaN                        Mar 2000   Jun 2000   Sep 2000   Dec 2000
# 1        NaN                           Count      Count      Count      Count
#
#   Unnamed: 10 Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ...  \
# 0    Mar 2001    Jun 2001    Sep 2001    Dec 2001    Mar 2002  ...
# 1       Count       Count       Count       Count       Count  ...
#
#   Unnamed: 176 Unnamed: 178 Unnamed: 180 Unnamed: 182 Unnamed: 184  \
# 0     Dec 2021     Mar 2022     Jun 2022     Sep 2022     Dec 2022
# 1        Count        Count        Count        Count        Count
#
#   Unnamed: 186 Unnamed: 188 Unnamed: 190 Unnamed: 192 Unnamed: 194
# 0     Mar 2023     Jun 2023     Sep 2023     Dec 2023     Mar 2024
# 1        Count        Count        Count        Count        Count
#
# [2 rows x 98 columns]

# %% [markdown]
# From the above, we can note that there are no NULL values in the dataset

# %% [markdown]
# ## Time Series for Log Average of Median Rent

# %%
import numpy as np
def log_average(series):
    series = pd.to_numeric(series, errors='coerce')
    series = series.astype(float)
    log_values = np.log(series)
    log_mean = np.mean(log_values)
    return np.exp(log_mean)

# %%
m_log_ave_f1b = m_flat_1b.iloc[:, 1:].apply(log_average)
m_log_ave_f2b = m_flat_2b.iloc[:, 1:].apply(log_average)
m_log_ave_f3b = m_flat_3b.iloc[:, 1:].apply(log_average)

m_log_ave_h2b = m_house_2b.iloc[:, 1:].apply(log_average)
m_log_ave_h3b = m_house_3b.iloc[:, 1:].apply(log_average)
m_log_ave_h4b = m_house_4b.iloc[:, 1:].apply(log_average)

m_log_ave_all = m_all_props.iloc[:, 1:].apply(log_average)


m_log_ave_f1b
# Out:
# march_2000        111.112737
# june_2000         112.623281
# september_2000    114.461180
# december_2000     114.908691
# march_2001        116.529520
#                      ...
# march_2023        316.963313
# june_2023         326.945262
# september_2023    338.625789
# december_2023     348.314602
# march_2024        360.534017
# Length: 97, dtype: float64

# %%
m_log_ave_f1b = pd.DataFrame(m_log_ave_f1b)
m_log_ave_f2b = pd.DataFrame(m_log_ave_f2b)
m_log_ave_f3b = pd.DataFrame(m_log_ave_f3b)

m_log_ave_h2b = pd.DataFrame(m_log_ave_h2b)
m_log_ave_h3b = pd.DataFrame(m_log_ave_h3b)
m_log_ave_h4b = pd.DataFrame(m_log_ave_h4b)

m_log_ave_all = pd.DataFrame(m_log_ave_all)


print(m_log_ave_f1b.index)
# the months are the index and the values are the first column
# Out:
# Index(['march_2000', 'june_2000', 'september_2000', 'december_2000',
#        'march_2001', 'june_2001', 'september_2001', 'december_2001',
#        'march_2002', 'june_2002', 'september_2002', 'december_2002',
#        'march_2003', 'june_2003', 'september_2003', 'december_2003',
#        'march_2004', 'june_2004', 'september_2004', 'december_2004',
#        'march_2005', 'june_2005', 'september_2005', 'december_2005',
#        'march_2006', 'june_2006', 'september_2006', 'december_2006',
#        'march_2007', 'june_2007', 'september_2007', 'december_2007',
#        'march_2008', 'june_2008', 'september_2008', 'december_2008',
#        'march_2009', 'june_2009', 'september_2009', 'december_2009',
#        'march_2010', 'june_2010', 'september_2010', 'december_2010',
#        'march_2011', 'june_2011', 'september_2011', 'december_2011',
#        'march_2012', 'june_2012', 'september_2012', 'december_2012',
#        'march_2013', 'june_2013', 'september_2013', 'december_2013',
# ...

# %%
first = (m_log_ave_f1b.iloc[:,0])
first
# Out:
# march_2000        111.112737
# june_2000         112.623281
# september_2000    114.461180
# december_2000     114.908691
# march_2001        116.529520
#                      ...
# march_2023        316.963313
# june_2023         326.945262
# september_2023    338.625789
# december_2023     348.314602
# march_2024        360.534017
# Name: 0, Length: 97, dtype: float64

# %%
dates = pd.to_datetime((m_log_ave_f1b.iloc[:, :-1]).index, format='%B_%Y')
print(dates)
# Out:
# DatetimeIndex(['2000-03-01', '2000-06-01', '2000-09-01', '2000-12-01',
#                '2001-03-01', '2001-06-01', '2001-09-01', '2001-12-01',
#                '2002-03-01', '2002-06-01', '2002-09-01', '2002-12-01',
#                '2003-03-01', '2003-06-01', '2003-09-01', '2003-12-01',
#                '2004-03-01', '2004-06-01', '2004-09-01', '2004-12-01',
#                '2005-03-01', '2005-06-01', '2005-09-01', '2005-12-01',
#                '2006-03-01', '2006-06-01', '2006-09-01', '2006-12-01',
#                '2007-03-01', '2007-06-01', '2007-09-01', '2007-12-01',
#                '2008-03-01', '2008-06-01', '2008-09-01', '2008-12-01',
#                '2009-03-01', '2009-06-01', '2009-09-01', '2009-12-01',
#                '2010-03-01', '2010-06-01', '2010-09-01', '2010-12-01',
#                '2011-03-01', '2011-06-01', '2011-09-01', '2011-12-01',
#                '2012-03-01', '2012-06-01', '2012-09-01', '2012-12-01',
# ...

# %%
# Plot the data
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# 1 Bedroom Flats
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_f1b.iloc[:,0])
plt.title('1 Bedroom Flats :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/1bFlat_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# 2 Bedroom Flats
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_f2b.iloc[:,0])
plt.title('2 Bedroom Flats :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/2bFlat_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# 3 Bedroom Flats
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_f3b.iloc[:,0])
plt.title('3 Bedroom Flats :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/3bFlat_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# 2 Bedroom Houses
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_h2b.iloc[:,0])
plt.title('2 Bedroom Houses :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/2bHouse_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# 3 Bedroom Houses
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_h3b.iloc[:,0])
plt.title('3 Bedroom Houses :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/3bHouse_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# 4 Bedroom Houses
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_h4b.iloc[:,0])
plt.title('4 Bedroom Houses :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/4bHouse_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# Plot the data
plt.figure(figsize=(12, 3))
plt.plot(dates, m_log_ave_all.iloc[:,0])
plt.title('All Properties :\nTime Series Plot of the Log Average of Median Weekly Rent')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')
plt.savefig('../data/plots/All_MedianTimeSeries.png', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 6))

# Plot each time series with a unique color and label for the legend
plt.plot(dates, m_log_ave_f1b.iloc[:, 0], label='1 Bedroom Flats', color='blue')
plt.plot(dates, m_log_ave_f2b.iloc[:, 0], label='2 Bedroom Flats', color='green')
plt.plot(dates, m_log_ave_f3b.iloc[:, 0], label='3 Bedroom Flats', color='orange')
plt.plot(dates, m_log_ave_h2b.iloc[:, 0], label='2 Bedroom Houses', color='red')
plt.plot(dates, m_log_ave_h3b.iloc[:, 0], label='3 Bedroom Houses', color='purple')
plt.plot(dates, m_log_ave_h4b.iloc[:, 0], label='4 Bedroom Houses', color='brown')
plt.plot(dates, m_log_ave_all.iloc[:, 0], label='All Properties', color='black')

# Title
plt.title('Time Series Plot of the Log Average of Median Weekly Rent for Different Property Types')
plt.xlabel('Year')
plt.ylabel('Log Average of Median Weekly Rent')

# Add a legend 
plt.legend(loc='upper left')
plt.savefig('../data/plots/Combined_MedianTimeSeries.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Time Series for the Number of Properties

# %%
#Flats
count_log_ave_f1b = c_flat_1b.iloc[:, 1:].apply(log_average)
count_log_ave_f1b = pd.DataFrame(count_log_ave_f1b)

count_log_ave_f2b = c_flat_2b.iloc[:, 1:].apply(log_average)
count_log_ave_f2b = pd.DataFrame(count_log_ave_f2b)

count_log_ave_f3b = c_flat_3b.iloc[:, 1:].apply(log_average)
count_log_ave_f3b = pd.DataFrame(count_log_ave_f3b)


#Houses
count_log_ave_h2b = c_house_2b.iloc[:, 1:].apply(log_average)
count_log_ave_h2b = pd.DataFrame(count_log_ave_h2b)

count_log_ave_h3b = c_house_3b.iloc[:, 1:].apply(log_average)
count_log_ave_h3b = pd.DataFrame(count_log_ave_h3b)

count_log_ave_h4b = c_house_4b.iloc[:, 1:].apply(log_average)
count_log_ave_h4b = pd.DataFrame(count_log_ave_h4b)

#All
count_log_ave_all = c_all_props.iloc[:, 1:].apply(log_average)
count_log_ave_all = pd.DataFrame(count_log_ave_all)

print(count_log_ave_h4b)
# Out:
#                                           0
# Lease commenced in year ending    53.889470
# Unnamed: 4                        51.543021
# Unnamed: 6                        50.485578
# Unnamed: 8                        52.082475
# Unnamed: 10                       51.755538
# ...                                     ...
# Unnamed: 186                     123.968826
# Unnamed: 188                     125.773029
# Unnamed: 190                     122.139700
# Unnamed: 192                     122.584737
# Unnamed: 194                     119.830391
#
# [97 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Plot the data
plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_f1b.iloc[:,0])
plt.title('1 Bedroom Flats:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/1bFlat_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_f2b.iloc[:,0])
plt.title('2 Bedroom Flats:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/2bFlat_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_f3b.iloc[:,0])
plt.title('3 Bedroom Flats:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/3bFlat_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()


plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_h2b.iloc[:,0])
plt.title('2 Bedroom Houses:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/2bHouse_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_h3b.iloc[:,0])
plt.title('3 Bedroom Houses:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/3bHouse_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_h4b.iloc[:,0])
plt.title('4 Bedroom Houses:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/4bHouse_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(12, 3))
plt.plot(dates, count_log_ave_all.iloc[:,0])
plt.title('All Properties:\nTime Series of the Log Average of Number of Available Rental Properties')
plt.xlabel('Year')
plt.ylabel('Log Average of \n Number of Available Rental Properties')
plt.savefig('../data/plots/All_CountTimeSeries.png', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

# Plot each time series with a unique color and label for the legend
plt.plot(dates, count_log_ave_f1b.iloc[:, 0], label='1 Bedroom Flats', color='blue')
plt.plot(dates, count_log_ave_f2b.iloc[:, 0], label='2 Bedroom Flats', color='green')
plt.plot(dates, count_log_ave_f3b.iloc[:, 0], label='3 Bedroom Flats', color='orange')
plt.plot(dates, count_log_ave_h2b.iloc[:, 0], label='2 Bedroom Houses', color='red')
plt.plot(dates, count_log_ave_h3b.iloc[:, 0], label='3 Bedroom Houses', color='purple')
plt.plot(dates, count_log_ave_h4b.iloc[:, 0], label='4 Bedroom Houses', color='brown')

# Title 
plt.title('Time Series of the Log Average of Number of Available Rental Properties for Different Property Types')
plt.xlabel('Year')
plt.ylabel('Log Average of Number of Available Rental Properties')

# Add a legend
plt.legend(loc='upper left')
plt.savefig('../data/plots/Combined_CountTimeSeries.png', bbox_inches='tight')
plt.show()

# %%
m_flat_1b
# Out:
#                                    suburbs march_2000 june_2000  \
# 2    Albert Park-Middle Park-West St Kilda        165       165
# 3                                 Armadale        150       150
# 4                            Carlton North        150       155
# 5                        Carlton-Parkville        165       170
# 6                          CBD-St Kilda Rd        250       250
# ..                                     ...        ...       ...
# 155                              Traralgon         75        75
# 156                            Wanagaratta         85        85
# 157                               Warragul         80        75
# 158                            Warrnambool         75        75
# 159                                Wodonga         85        85
#
#     september_2000 december_2000 march_2001 june_2001 september_2001  \
# 2              170           175        180       185            190
# ...

# %% [markdown]
# ## Growth Calculation

# %%
# Convert all datatypes to numeric datatypes for growth calculation 
columns_to_convert = new_header[1:]

m_flat_1b.loc[:, columns_to_convert] = m_flat_1b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')
m_flat_2b.loc[:, columns_to_convert] = m_flat_2b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')
m_flat_3b.loc[:, columns_to_convert] = m_flat_3b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')

m_house_2b.loc[:, columns_to_convert] = m_house_2b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')
m_house_3b.loc[:, columns_to_convert] = m_house_3b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')
m_house_4b.loc[:, columns_to_convert] = m_house_4b.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')

m_all_props.loc[:, columns_to_convert] = m_all_props.loc[:, columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
##### calculate 20 year growth for all datasets 
# Initialize the new dataframe
growth_rate_20_years = pd.DataFrame()

# Copy the suburbs column
growth_rate_20_years['suburbs'] = m_flat_1b['suburbs']
growth_rate_20_years['1_bed_flats'] = ((m_flat_1b['march_2024'] - m_flat_1b['march_2004']) / m_flat_1b['march_2004'])
growth_rate_20_years['2_bed_flats'] = ((m_flat_2b['march_2024'] - m_flat_2b['march_2004']) / m_flat_2b['march_2004'])
growth_rate_20_years['3_bed_flats'] = ((m_flat_3b['march_2024'] - m_flat_3b['march_2004']) / m_flat_3b['march_2004'])


growth_rate_20_years['2_bed_houses'] = ((m_house_2b['march_2024'] - m_house_2b['march_2004']) / m_house_2b['march_2004'])
growth_rate_20_years['3_bed_houses'] = ((m_house_3b['march_2024'] - m_house_3b['march_2004']) / m_house_3b['march_2004'])
growth_rate_20_years['4_bed_houses'] = ((m_house_4b['march_2024'] - m_house_4b['march_2004']) / m_house_4b['march_2004'])

growth_rate_20_years['all_properties'] = ((m_all_props['march_2024'] - m_all_props['march_2004']) / m_all_props['march_2004'])

growth_rate_20_years1= growth_rate_20_years.dropna(subset='suburbs')
growth_rate_20_years1

# Fill the first row with NaN or any placeholder value if needed
#growth_rate_20_years.iloc[0, growth_rate_20_years.columns.get_loc('growth_flat_1b')] = None
# Out:
#                                    suburbs 1_bed_flats 2_bed_flats  \
# 2    Albert Park-Middle Park-West St Kilda       1.125    1.083333
# 3                                 Armadale    1.388889       1.375
# 4                            Carlton North    1.247191    1.156863
# 5                        Carlton-Parkville    1.368421    1.133333
# 6                          CBD-St Kilda Rd    1.115385         1.0
# ..                                     ...         ...         ...
# 155                              Traralgon      2.4375    1.615385
# 156                            Wanagaratta    1.666667         1.4
# 157                               Warragul     1.26087    1.482759
# 158                            Warrnambool         2.0    1.714286
# 159                                Wodonga         1.6         1.3
#
#     3_bed_flats 2_bed_houses 3_bed_houses 4_bed_houses all_properties
# 2      1.009346     1.108571     1.682353     1.311912       1.166667
# ...

# %%
##### UNNECESSARY - ODO NOT RUN
# import pandas as pd

# df = growth_rate_20_years

# # List of 68 Yarra Ranges suburbs 
# suburb_yr = [
#     'Badger Creek', 'Beenak', 'Belgrave', 'Belgrave Heights', 'Belgrave South', 'Big Pats Creek', 
#     'Cambarville', 'Chirnside Park', 'Chum Creek', 'Coldstream', 'Dixons Creek', 'Don Valley', 
#     'East Warburton', 'Emerald', 'Fernshaw', 'Ferny Creek', 'Gilderoy', 'Gladysdale', 
#     'Gruyere', 'Healesville', 'Hoddles Creek', 'Kallista', 'Kalorama', 'Kilsyth', 
#     'Launching Place', 'Lilydale', 'Lysterfield', 'Macclesfield', 'Matlock', 'McMahons Creek', 
#     'Menzies Creek', 'Millgrove', 'Monbulk', 'Montrose', 'Mooroolbark', 'Mount Dandenong', 
#     'Mount Evelyn', 'Mount Toolebewong', 'Narre Warren East', 'Olinda', 'Powelltown', 'Reefton', 
#     'Sassafras', 'Selby', 'Seville', 'Seville East', 'Sherbrooke', 'Silvan', 'Steels Creek', 
#     'Tarrawarra', 'Tecoma', 'The Patch', 'Three Bridges', 'Toolangi', 'Toorongo', 
#     'Tremont', 'Upper Ferntree Gully', 'Upwey', 'Wandin East', 'Wandin North', 'Warburton', 
#     'Wesburn', 'Wonga Park', 'Woori Yallock', 'Yarra Glen', 'Yarra Junction', 'Yellingbo', 'Yering'
# ]

# # Ensure case insensitivity by converting 'suburbs' column to lowercase
# df['suburbs'] = df['suburbs'].str.lower()

# # Duplicate 'yarra ranges' row 68 times and replace with suburbs 
# row_yarra_ranges = df[df['suburbs'] == 'yarra ranges'].copy()
# if len(row_yarra_ranges) > 0:
#     row_yarra_ranges_duplicated = pd.concat([row_yarra_ranges] * 68, ignore_index=True)
#     row_yarra_ranges_duplicated['suburbs'] = suburb_yr
# else:
#     row_yarra_ranges_duplicated = pd.DataFrame()  # Empty in case 'yarra ranges' not found

# # Remove the original'yarra ranges' rows from the DataFrame
# df_cleaned = df[~df['suburbs'].isin(['yarra ranges'])]


# growth_rate_20_years = pd.concat([df_cleaned, row_yarra_ranges_duplicated], ignore_index=True)

# # Capitalizing 'suburbs'
# growth_rate_20_years['suburbs'] = growth_rate_20_years['suburbs'].str.title()

# print(growth_rate_20_years)

# %%
print(RAI_df)
# Out:
#                                    suburbs     f1B_RAI     f2B_RAI  \
# 2    Albert Park-Middle Park-West St Kilda  259.764706  184.000000
# 3                                 Armadale  256.744186  193.684211
# 4                            Carlton North  276.000000  200.727273
# 5                        Carlton-Parkville  245.333333  172.500000
# 6                          CBD-St Kilda Rd  200.727273  157.714286
# ..                                     ...         ...         ...
# 155                              Traralgon  401.454545  324.705882
# 156                            Wanagaratta  460.000000  368.000000
# 157                               Warragul  424.615385  306.666667
# 158                            Warrnambool  368.000000  290.526316
# 159                                Wodonga  424.615385  320.000000
#
#         f3B_RAI     h2B_RAI     h3B_RAI     h4B_RAI     all_RAI
# 2    128.372093  149.593496   96.842105   74.847458  169.846154
# ...

# %%
import pandas as pd

# Load your parquet file with locality and postcode information
parquet_file_path = '../data/postcodes/postcodes.parquet'
locality_postcode_df = pd.read_parquet(parquet_file_path)

# Load the DataFrame with growth rate
df_gr = growth_rate_20_years1 

# Convert both 'suburbs' and 'locality' columns to lowercase to ensure case-insensitive matching
df_gr['suburbs'] = df_gr['suburbs'].str.lower().str.strip()
locality_postcode_df['locality'] = locality_postcode_df['locality'].str.lower().str.strip()

# Merge the two DataFrames based on the suburb/locality
df_merged = pd.merge(df_gr, locality_postcode_df[['locality', 'postcode']], 
                     left_on='suburbs', right_on='locality', how='left')


# Drop the 'locality' column if it's no longer needed after the merge
df_gr1 = df_merged.drop_duplicates(subset=['suburbs'])

print(df_gr1)

#adding suburb postcodes manually where code didn't work
suburb_postcode_mapping = {
    'cbd-st kilda rd':3000,
    'fitzroy north-clifton hill':3068,
    'flemington-kensington':3031,
    'albert park-middle park-west st kilda':3206,
    'north melbourne-west melbourne':3051,
    'prahran-windsor':3181,
    'richmond-burnley':3121,
    'bulleen-templestowe-doncaster':3108,
    'burwood-ashburton':3125,
    'camberwell-glen iris':3146,

    'canterbury-surrey hills-mont albert':3127,
    'chadstone-oakleigh':3166,
    'doncaster east-donvale':3109,
    'glen waverley-mulgrave':3150,
    'nunawading-mitcham':3132,
    'vermont-forest hill-burwood east':3151,
    'aspendale-chelsea-carrum':3195,
    'hampton-beaumaris':3188,
    'mentone-parkdale-mordialloc':3194,
    'murrumbeena-hughesdale':3163,

    'newport-spotswood': 3015,
    'st albans-deer park': 3022,
    'werribee-hoppers crossing': 3030,
    'yarraville-seddon': 3013,
    'broadmeadows-roxburgh park': 3047,
    'coburg-pascoe vale south': 3044,
    'gladstone park-tullamarine': 3043,
    'moonee ponds-ascot vale': 3039,
    'oak park-glenroy-fawkner': 3046,
    'pascoe vale-coburg north': 3058,

    'bundoora-greensborough-hurstbridge': 3088,
    'eltham-research-montmorency': 3095,
    'fairfield-alphington': 3078,
    'heidelberg-heidelberg west': 3084,
    'ivanhoe-ivanhoe east': 3079,
    'mill park-epping': 3076,
    'thomastown-lalor': 3075,
    'croydon-lilydale': 3140,
    'wantirna-scoresby': 3152,
    'dandenong north-endeavour hills': 3175,

    'narre warren-hampton park': 3805,
    'dromana-portsea': 3944,
    'hastings-flinders': 3929,
    'mt eliza-mornington-mt martha': 3931,
    'seaford-carrum downs': 3198,
    'belmont-grovedale': 3216,
    'geelong-newcombe': 3220,
    'herne hill-geelong west': 3218,
    'mount clear-buninyong': 3357,
    'sebastopol-delacombe': 3356,

    'wendouree-alfredton':3350,
    'flora hill-bendigo east':3550,
    'golden square-kangaroo flat':3555,
    'sale-maffra': 3850,
    'carlton-parkville':3052,
    'collingwood-abbotsford': 3066,
    'docklands': 3006,
    'malvern': 3144,
    'keilor east-avondale heights': 3034,
    'yarra ranges': 3777,

    'west st kilda': 3182,   # Example postcode   
    'st kilda rd': 3004,
    'east st kilda': 3183,
    'east hawthorn': 3123,
    'east brunswick': 3057,
    'west brunswick': 3055,
    'mt eliza': 3930,
    'mt martha': 3934,
    'newcombe': 3219,  # Assuming this is Newcomb, correct the name if needed
    'bendigo east': 3550,

    'moe-newborough': 3825,
    'wanagaratta': 3677 , # Assuming 'wanagaratta' is Wangaratta
    'ocean grove-barwon heads': 3226
}

def update_postcode(suburb):
    return suburb_postcode_mapping.get(suburb, pd.NA)

# Apply the update to the postcode column where postcodes are missing
df_merged['postcode'] = df_merged.apply(
    lambda row: update_postcode(row['suburbs']) if pd.isna(row['postcode']) else row['postcode'],
    axis=1
)

# Apply the update to the postcode column where postcodes are missing
df_merged['postcode'] = df_merged.apply(
    lambda row: update_postcode(row['suburbs']) if pd.isna(row['postcode']) else row['postcode'],
    axis=1
)

# Remove the row where the 'suburbs' column has the value 'group total'
df_merged = df_merged[df_merged['suburbs'].str.lower() != 'group total']

df_merged['postcode'] = df_merged['postcode'].astype('Int64')

# Alternatively, convert the postcode to a string to remove decimals
df_merged['postcode'] = df_merged['postcode'].astype(str)

df_merged = df_merged.drop_duplicates(subset=['suburbs'])

# Show the result with postcodes merged
df_merged.head()
# Out:
#                                    suburbs 1_bed_flats 2_bed_flats  \
# 0    albert park-middle park-west st kilda       1.125    1.083333
# 1                                 armadale    1.388889       1.375
# 2                            carlton north    1.247191    1.156863
# 3                        carlton-parkville    1.368421    1.133333
# 4                          cbd-st kilda rd    1.115385         1.0
# ..                                     ...         ...         ...
# 151                              traralgon      2.4375    1.615385
# 152                            wanagaratta    1.666667         1.4
# 153                               warragul     1.26087    1.482759
# 154                            warrnambool         2.0    1.714286
# 155                                wodonga         1.6         1.3
#
#     3_bed_flats 2_bed_houses 3_bed_houses 4_bed_houses all_properties  \
# 0      1.009346     1.108571     1.682353     1.311912       1.166667
# ...

# %%
# m_sub_df_filled['3+ Bedder Affordability Metrics']

# %%
# frames = [df_merged['postcode'], m_sub_df_filled['1-2 Bedder Affordability Metrics'],m_sub_df_filled['3+ Bedder Affordability Metrics']]
# affordability = pd.concat(frames, axis = 1)
# affordability2 = affordability.dropna(subset=['postcode'])
# print(affordability2)

# %%
nan_rows = df_merged[df_merged['postcode'].isna()]

print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [suburbs, 1_bed_flats, 2_bed_flats, 3_bed_flats, 2_bed_houses, 3_bed_houses, 4_bed_houses, all_properties, locality, postcode]
# Index: []

# %% [markdown]
# there are no null postcode values

# %%
## rearrange the columns so that the  postcodes will be the first column
cols = df_merged.columns.tolist()
new_cols = [cols[-1]] + cols[:-1]
rearranged_df = df_merged[new_cols]
rearranged_df = rearranged_df.drop('suburbs', axis = 1)
print(rearranged_df)
# Out:
#     postcode 1_bed_flats 2_bed_flats 3_bed_flats 2_bed_houses 3_bed_houses  \
# 0       3206       1.125    1.083333    1.009346     1.108571     1.682353
# 1       3143    1.388889       1.375    1.571429     1.279412     1.386364
# 2       3054    1.247191    1.156863    1.102102     1.420495          1.5
# 3       3052    1.368421    1.133333    1.393768     1.166667       1.0575
# 4       3000    1.115385         1.0    1.173913          NaN          NaN
# ..       ...         ...         ...         ...          ...          ...
# 151     3844      2.4375    1.615385    1.371429       1.3125     1.428571
# 152     3677    1.666667         1.4       1.375     1.642857     1.545455
# 153     3820     1.26087    1.482759    1.682432     1.533333     1.444444
# 154     3280         2.0    1.714286       1.525     1.371429          1.5
# 155     3689         1.6         1.3    1.222222        1.375         1.25
#
#     4_bed_houses all_properties       locality
# ...

# %%
RAI_df['postcode'] = rearranged_df['postcode']
RAI_df
# Out:
#                                    suburbs     f1B_RAI     f2B_RAI  \
# 2    Albert Park-Middle Park-West St Kilda  259.764706  184.000000
# 3                                 Armadale  256.744186  193.684211
# 4                            Carlton North  276.000000  200.727273
# 5                        Carlton-Parkville  245.333333  172.500000
# 6                          CBD-St Kilda Rd  200.727273  157.714286
# ..                                     ...         ...         ...
# 155                              Traralgon  401.454545  324.705882
# 156                            Wanagaratta  460.000000  368.000000
# 157                               Warragul  424.615385  306.666667
# 158                            Warrnambool  368.000000  290.526316
# 159                                Wodonga  424.615385  320.000000
#
#         f3B_RAI     h2B_RAI     h3B_RAI     h4B_RAI     all_RAI postcode
# 2    128.372093  149.593496   96.842105   74.847458  169.846154     3054
# ...

# %%
test_df = rearranged_df[rearranged_df['postcode'] == '3850']
test_df
# Out:
#     postcode 1_bed_flats 2_bed_flats 3_bed_flats 2_bed_houses 3_bed_houses  \
# 144     3850    1.888889        1.88    1.966667     1.961538          1.8
#
#     4_bed_houses all_properties locality
# 144     1.173913            2.0      NaN

# %%
output_relative_dir = '../data/landing'

# check if it exists as it makedir will raise an error if it does exist
if not os.path.exists(output_relative_dir):
    os.makedirs(output_relative_dir)

# %%
rearranged_df.to_parquet('../data/landing/growth_rate_20years.parquet', index = False)

# %%
RAI_df.to_parquet('../data/landing/RAI.parquet')

# %%
# affordability.to_parquet('../data/landing/affordability.parquet', index = False)
# rearranged_df.to_parquet('../data/landing/growth_rate_20years.parquet', index = False)

# %%
from pyspark.sql import SparkSession
#Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("Liveability")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .config('spark.driver.memory', '4g')
    .config('spark.executor.memory', '2g')
    .getOrCreate()
)
df = spark.read.parquet('../data/landing/growth_rate_20years.parquet', header=True, inferSchema=True)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# Picked up _JAVA_OPTIONS: -Xmx2048m
# Picked up _JAVA_OPTIONS: -Xmx2048m
# 24/10/09 10:37:35 WARN Utils: Your hostname, Rachel resolves to a loopback address: 127.0.1.1; using 172.27.42.84 instead (on interface eth0)
# 24/10/09 10:37:35 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/09 10:37:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df.show()
# Out:
# +--------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+---------------+
# |postcode|       1_bed_flats|       2_bed_flats|       3_bed_flats|      2_bed_houses|      3_bed_houses|      4_bed_houses|    all_properties|       locality|
# +--------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+---------------+
# |    3206|             1.125|1.0833333333333333|1.0093457943925233|1.1085714285714285|1.6823529411764706| 1.311912225705329|1.1666666666666667|           NULL|
# |    3143|1.3888888888888888|             1.375|1.5714285714285714|1.2794117647058822|1.3863636363636365|1.5334608030592733|1.3333333333333333|       armadale|
# |    3054| 1.247191011235955|1.1568627450980393| 1.102102102102102|1.4204946996466432|               1.5|1.6666666666666667|1.2818791946308725|  carlton north|
# ...

# %% [markdown]
# ##### Obsolete codes

# %%
count_log_ave_all.to_csv('../data/rent/count.csv', index=False)
median_log_ave_all.to_csv('../data/rent/median.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 2
#       1 count_log_ave_all.to_csv('../data/rent/count.csv', index=False)
# ----> 2 median_log_ave_all.to_csv('../data/rent/median.csv', index=False)
#
# NameError: name 'median_log_ave_all' is not defined

# %% [markdown]
# ###### Backup Codes from here onwares

# %%
# Load the provided CSV file
file_path = '../data/rent/median.csv'
df = pd.read_csv(file_path)

# Select only columns for March, June, September, and December for each year
quarters = ['March', 'June', 'September', 'December']
quarter_columns = [col for col in df.columns if any(q in col for q in quarters)]

# Subset the dataframe to include only the quarterly columns
df_quarters = df[['suburbs'] + quarter_columns]

# Convert the quarterly columns to numeric, if they aren't already
df_quarters[quarter_columns] = df_quarters[quarter_columns].apply(pd.to_numeric, errors='coerce')

# Calculate the average rental price for each year by averaging March, June, September, and December
# First, create a mapping of years
years = sorted(set([col.split(' ')[-1] for col in quarter_columns]))

# Create a DataFrame to store the yearly averages
df_yearly_avg = pd.DataFrame()

for year in years:
    # Get columns for March, June, September, and December of each year
    year_columns = [col for col in quarter_columns if year in col]
    # Calculate the mean for those four months
    df_yearly_avg[year] = df_quarters[year_columns].mean(axis=1)

# Calculate the average price across all suburbs for each year
annual_avg_price = df_yearly_avg.mean()

# Calculate the year-over-year percentage change
annual_price_change = annual_avg_price.pct_change() * 100

# Combine the results into a DataFrame
df_annual_change = pd.DataFrame({
    'Year': annual_avg_price.index,
    'Average Price': annual_avg_price.values,
    'Price Change (%)': annual_price_change.values
})

# Display the results
df_annual_change

# %%
# Load the provided CSV file
file_path = '../data/rent/median.csv'
df = pd.read_csv(file_path)

# Select only columns for March, June, September, and December for each year
quarters = ['March', 'June', 'September', 'December']
quarter_columns = [col for col in df.columns if any(q in col for q in quarters)]

# Subset the dataframe to include only the quarterly columns and the suburb names
df_quarters = df[['suburbs'] + quarter_columns]

# Convert the quarterly columns to numeric, if they aren't already
df_quarters[quarter_columns] = df_quarters[quarter_columns].apply(pd.to_numeric, errors='coerce')

# Get a list of years from the column names
years = sorted(set([col.split(' ')[-1] for col in quarter_columns]))

# Create a DataFrame to store the yearly averages for each suburb
df_yearly_avg_suburbs = pd.DataFrame()

for year in years:
    # Get columns for March, June, September, and December of the current year
    year_columns = [col for col in quarter_columns if year in col]
    # Calculate the mean for those four months for each suburb
    df_yearly_avg_suburbs[year] = df_quarters[year_columns].mean(axis=1)

# Set the suburb names as the index
df_yearly_avg_suburbs.index = df_quarters['suburbs']

# Calculate the year-over-year percentage change for each suburb, 
df_yearly_change_suburbs = df_yearly_avg_suburbs.pct_change(axis=1)

# Display the results for each suburb
df_yearly_change_suburbs

df = df_yearly_change_suburbs

# Remove year 2000 values as they will be null
del df['2000']


# Reset the index so that the suburb names become a regular column
df.reset_index(inplace=True)

print(df)

# %% [markdown]
# Splitting suburbs that are joined together and have same data values

# %%
def split_and_expand(df, column_to_split, delimiter='-'):
    # Split the suburb column 
    df_split = df[column_to_split].str.split(delimiter, expand=True)
    
    # Melt the split columns into a long format
    df_melted = pd.DataFrame(df_split.stack(), columns=[column_to_split]).reset_index(level=1, drop=True)
    
   
    df_expanded = df_melted.merge(df.drop(columns=[column_to_split]), left_index=True, right_index=True)
    
    return df_expanded


df_expanded = split_and_expand(df, 'suburbs')

print(df_expanded)

# %%
import pandas as pd

df = df_expanded

# List of 68 Yarra Ranges suburbs 
suburb_yr = [
    'Badger Creek', 'Beenak', 'Belgrave', 'Belgrave Heights', 'Belgrave South', 'Big Pats Creek', 
    'Cambarville', 'Chirnside Park', 'Chum Creek', 'Coldstream', 'Dixons Creek', 'Don Valley', 
    'East Warburton', 'Emerald', 'Fernshaw', 'Ferny Creek', 'Gilderoy', 'Gladysdale', 
    'Gruyere', 'Healesville', 'Hoddles Creek', 'Kallista', 'Kalorama', 'Kilsyth', 
    'Launching Place', 'Lilydale', 'Lysterfield', 'Macclesfield', 'Matlock', 'McMahons Creek', 
    'Menzies Creek', 'Millgrove', 'Monbulk', 'Montrose', 'Mooroolbark', 'Mount Dandenong', 
    'Mount Evelyn', 'Mount Toolebewong', 'Narre Warren East', 'Olinda', 'Powelltown', 'Reefton', 
    'Sassafras', 'Selby', 'Seville', 'Seville East', 'Sherbrooke', 'Silvan', 'Steels Creek', 
    'Tarrawarra', 'Tecoma', 'The Patch', 'Three Bridges', 'Toolangi', 'Toorongo', 
    'Tremont', 'Upper Ferntree Gully', 'Upwey', 'Wandin East', 'Wandin North', 'Warburton', 
    'Wesburn', 'Wonga Park', 'Woori Yallock', 'Yarra Glen', 'Yarra Junction', 'Yellingbo', 'Yering'
]

# Ensure case insensitivity by converting 'suburbs' column to lowercase
df['suburbs'] = df['suburbs'].str.lower()

# Duplicate 'yarra ranges' row 68 times and replace with suburbs 
row_yarra_ranges = df[df['suburbs'] == 'yarra ranges'].copy()
if len(row_yarra_ranges) > 0:
    row_yarra_ranges_duplicated = pd.concat([row_yarra_ranges] * 68, ignore_index=True)
    row_yarra_ranges_duplicated['suburbs'] = suburb_yr
else:
    row_yarra_ranges_duplicated = pd.DataFrame()  # Empty in case 'yarra ranges' not found

# Remove the original'yarra ranges' rows from the DataFrame
df_cleaned = df[~df['suburbs'].isin(['yarra ranges'])]


df_expanded = pd.concat([df_cleaned, row_yarra_ranges_duplicated], ignore_index=True)

# Capitalizing 'suburbs'
df_expanded['suburbs'] = df_expanded['suburbs'].str.title()

print(df_expanded)

# %% [markdown]
# Get poscodes for suburbs

# %%
import pandas as pd

# Load your parquet file with locality and postcode information
parquet_file_path = '../data/postcodes/postcodes.parquet'
locality_postcode_df = pd.read_parquet(parquet_file_path)

# Load the DataFrame with rental prediction data
df_rental_predictions = df_expanded

# Convert both 'suburbs' and 'locality' columns to lowercase to ensure case-insensitive matching
df_rental_predictions['suburbs'] = df_rental_predictions['suburbs'].str.lower().str.strip()
locality_postcode_df['locality'] = locality_postcode_df['locality'].str.lower().str.strip()

# Merge the two DataFrames based on the suburb/locality
df_merged = pd.merge(df_rental_predictions, locality_postcode_df[['locality', 'postcode']], 
                     left_on='suburbs', right_on='locality', how='left')

# Drop the 'locality' column if it's no longer needed after the merge
df_merged.drop(columns=['locality'], inplace=True)

#adding suburb postcodes manually where code didn't work
suburb_postcode_mapping = {
    'cbd':3000,
    'west st kilda': 3182,   # Example postcode   
    'st kilda rd': 3004,
    'east st kilda': 3183,
    'east hawthorn': 3123,
    'east brunswick': 3057,
    'west brunswick': 3055,
    'mt eliza': 3930,
    'mt martha': 3934,
    'newcombe': 3219,  # Assuming this is Newcomb, correct the name if needed
    'bendigo east': 3550,
    'wanagaratta': 3677  # Assuming 'wanagaratta' is Wangaratta
}

def update_postcode(suburb):
    return suburb_postcode_mapping.get(suburb, pd.NA)

# Apply the update to the postcode column where postcodes are missing
df_merged['postcode'] = df_merged.apply(
    lambda row: update_postcode(row['suburbs']) if pd.isna(row['postcode']) else row['postcode'],
    axis=1
)

# Remove the row where the 'suburbs' column has the value 'group total'
df_merged = df_merged[df_merged['suburbs'].str.lower() != 'group total']

df_merged['postcode'] = df_merged['postcode'].astype('Int64')

# Alternatively, convert the postcode to a string to remove decimals
df_merged['postcode'] = df_merged['postcode'].astype(str)

# Show the result with postcodes merged
print(df_merged)

# %% [markdown]
# Removing suburb names to avoid problems while merging

# %%
df_qra = df_merged.drop(columns=['suburbs'])

# Drop 'suburbs' 
df_qra = df_merged.drop(columns=['suburbs'])

# Bringing 'postcode' forward
cols = ['postcode'] + [col for col in df_qra.columns if col != 'postcode']
df_qra = df_qra[cols]
print(df_qra)

df_qra.to_parquet('../data/curated/qra.parquet', index=False)
