# %%
import pandas as pd
import pyarrow as pa
from pyarrow import json
import pyarrow.parquet as pq

df = pd.read_json('../data/raw/example.json')

# %%
pd.DataFrame(df)
# Out:
#           https://www.domain.com.au/667-glenhuntly-road-caulfield-vic-3162-11598047  \
# name                 667 Glenhuntly Road, Caulfield VIC 3162
# cost_text                 $38,000 p.a. Incl. Outgoings + GST
# rooms                                                     []
# parking                                                   []
# desc                Can you hear it? Opportunity knocking!!
#
#           https://www.domain.com.au/6501-35-queensbridge-street-southbank-vic-3006-16869807  \
# name         6501/35 Queensbridge Street, Southbank VIC 3006
# cost_text                                         $12,500 pw
# rooms                                      [4 Beds, 4 Baths]
# parking                                          [2 Parking]
# desc       Unparalleled space and bathed in natural light...
#
#           https://www.domain.com.au/7-jeffcott-street-west-melbourne-vic-3003-17038576  \
# name              7 Jeffcott Street, West Melbourne VIC 3003
# ...

# %%
df = df.T

# %%
df.head()
# Out:
#                                                                                                name  \
# https://www.domain.com.au/667-glenhuntly-road-c...          667 Glenhuntly Road, Caulfield VIC 3162
# https://www.domain.com.au/6501-35-queensbridge-...  6501/35 Queensbridge Street, Southbank VIC 3006
# https://www.domain.com.au/7-jeffcott-street-wes...       7 Jeffcott Street, West Melbourne VIC 3003
# https://www.domain.com.au/5604-1-queensbridge-s...   5604/1 Queensbridge Square, Southbank VIC 3006
# https://www.domain.com.au/14a-ethel-street-malv...               14A Ethel Street, Malvern VIC 3144
#
#                                                                                             cost_text  \
# https://www.domain.com.au/667-glenhuntly-road-c...                 $38,000 p.a. Incl. Outgoings + GST
# https://www.domain.com.au/6501-35-queensbridge-...                                         $12,500 pw
# ...

# %%
from pyspark.sql import SparkSession

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("MAST30034 Tutorial 1")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .getOrCreate()
)

# immutable : once u create a df w data structure, the contents in the df cannot be changed
# any modifications on the df will create a new df
# csv stored in rows, parquet is stored in columns. 
# harder to index csv cause 1 row has lots of datatypes, 
# parquet : each column has the same datatype & cols are stored tgthr

# %%
import os

    # from the current `tute_1` directory, go back two levels to the `MAST30034` directory
output_relative_dir = '../data/'

# check if it exists as it makedir will raise an error if it does exist
if not os.path.exists(output_relative_dir):
    os.makedirs(output_relative_dir)
    
# now, for each type of data set we will need, we will create the paths
if not os.path.exists(output_relative_dir + 'scraped'):
    os.makedirs(output_relative_dir + 'scraped')

# %%
sdf = df.to_parquet('../data/scraped/property_data.parquet')

# %%
sdf = spark.read.parquet('../data/scraped/property_data.parquet')

# %%
sdf.show(10)
# Out:
# +--------------------+--------------------+-----------------+-----------+--------------------+--------------------+
# |                name|           cost_text|            rooms|    parking|                desc|   __index_level_0__|
# +--------------------+--------------------+-----------------+-----------+--------------------+--------------------+
# |667 Glenhuntly Ro...|$38,000 p.a. Incl...|               []|         []|Can you hear it? ...|https://www.domai...|
# |6501/35 Queensbri...|          $12,500 pw|[4 Beds, 4 Baths]|[2 Parking]|Unparalleled spac...|https://www.domai...|
# |7 Jeffcott Street...|           $9,999 pw|[5 Beds, 5 Baths]|[5 Parking]|This ad is for Of...|https://www.domai...|
# |5604/1 Queensbrid...|           $5,750.00|[2 Beds, 2 Baths]|[2 Parking]|Luxurious 2-bedro...|https://www.domai...|
# |14A Ethel Street,...|Fully Furn - $500...|[4 Beds, 4 Baths]|[2 Parking]| class="css-dxogl...|https://www.domai...|
# ...
